# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


def f(x):
  return 3*x**5 + 5*x**4 - 12*x**3 + 8*x**2 + 6*x - 10

def g(x):
  return 15*x**4 + 20*x*3 - 36*x**2 + 16*x +6



iteration = 87
tolerance = 0.002
initial_value = 6



def newton_raphson(x, iter):
    # update nilai x, dengan rumus newton rapshn
    x_new = x - f(x)/g(x)

    print(f"Iteration {iter}: {x_new}")
    
    #kalau sudah ketemu nilai f nya kurang dari toleransi, return
    if np.abs(f(x_new)) < tolerance:
        print(f"Root found at {x_new}")
        return x_new
    
    # validasi kalau lebih dari max iter
    if (iter >= iteration):
        print("Max iter reached")
        return
    
    
    return newton_raphson(x_new, iter+1)


newton_raphson(initial_value, 1)
# Out:
# Iteration 1: 4.520369773191444
# Iteration 2: 3.3595496834856045
# Iteration 3: 2.4725595767381234
# Iteration 4: 1.8430123536064125
# Iteration 5: 1.464101537369762
# Iteration 6: 1.2675482409124135
# Iteration 7: 1.1624764470419968
# Iteration 8: 1.1018126735452192
# Iteration 9: 1.0649469181947862
# Iteration 10: 1.0418642111451832
# Iteration 11: 1.0271557521142365
# Iteration 12: 1.0176837852127818
# Iteration 13: 1.0115440465145855
# Iteration 14: 1.0075478711870944
# Iteration 15: 1.0049400528431491
# Iteration 16: 1.0032353738458284
# Iteration 17: 1.0021198413028443
# Iteration 18: 1.0013893242176708
# Iteration 19: 1.0009107164891395
# Iteration 20: 1.0005970555076178
# Iteration 21: 1.0003914535301088
# Iteration 22: 1.0002566657923484
# Iteration 23: 1.0001682946709716
# Iteration 24: 1.0001103525326864
# Iteration 25: 1.0000723603265227
# Root found at 1.0000723603265227
# 1.0000723603265227
